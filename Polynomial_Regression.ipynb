# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
x = 6*np.random.rand(100,1) - 3
y = 0.5*x**2 + 1.5*x + 2 + np.random.randn(100,1)

#Quadratic Eqaution used -:  y = 0.5x^2+1.5x+2+outliers

# %%
plt.scatter(x,y,color ='g')
plt.xlabel('X Dataset')
plt.ylabel('Y Dataset')
# Out:
# Text(0, 0.5, 'Y Dataset')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train , y_test = train_test_split(x,y,test_size = 0.3 , random_state = 42)

x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((70, 1), (30, 1), (70, 1), (30, 1))

# %%
from sklearn.linear_model import LinearRegression
regression1  = LinearRegression()

# %%
regression1.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
sscore = r2_score(y_test , regression1.predict(x_test))
print(sscore)
# Out:
# 0.6597096178927648

# %%
##Visualization of the Model

plt.plot(x_train , regression1.predict(x_train) , color = 'r')
plt.scatter(x_train , y_train)

# %%
## Lets Apply Polynomial Regression
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree = 2 , include_bias = True)   ## Degree  = 2 means h_theta_x = h_0 + h1x1 + h2x^2
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.fit_transform(x_test)

# %%
x_test_poly  ## [Bias , x1_Feature , x^2 Feature ]
# Out:
# array([[ 1.        ,  2.54287048,  6.46619027],
#        [ 1.        ,  0.38838247,  0.15084094],
#        [ 1.        ,  0.36792184,  0.13536648],
#        [ 1.        , -1.79625499,  3.22653198],
#        [ 1.        ,  1.17202647,  1.37364605],
#        [ 1.        ,  1.6350647 ,  2.67343658],
#        [ 1.        , -2.23722384,  5.00517052],
#        [ 1.        ,  0.96627383,  0.93368511],
#        [ 1.        , -1.71590677,  2.94433605],
#        [ 1.        ,  1.47695024,  2.18138202],
#        [ 1.        ,  0.1874739 ,  0.03514646],
#        [ 1.        , -0.6669663 ,  0.44484404],
#        [ 1.        , -2.61054007,  6.81491945],
#        [ 1.        ,  1.11675272,  1.24713665],
#        [ 1.        ,  1.15219654,  1.32755687],
#        [ 1.        ,  2.00060283,  4.0024117 ],
#        [ 1.        ,  0.6775105 ,  0.45902047],
#        [ 1.        , -1.11351735,  1.2399209 ],
#        [ 1.        , -2.33344722,  5.44497595],
#        [ 1.        , -2.88744042,  8.3373122 ],
# ...

# %%
from sklearn.metrics import r2_score
regression = LinearRegression()
regression.fit(x_train_poly , y_train)
y_pred = regression.predict(x_test_poly)
score = r2_score(y_test , y_pred)
print(score)
# Out:
# 0.865750771967523

# %%
print(regression.coef_)
print(regression.intercept_)
# Out:
# [[0.         1.51388321 0.50666431]]
# [2.11249299]

# %%
plt.scatter(x_train , regression.predict(x_train_poly))
plt.plot(x_train , y_train )

# %%
poly = PolynomialFeatures(degree = 3 , include_bias = True)   ## Degree  = 3 means h_theta_x = h_0 + h1x1 + h2x^2 + h3x^3
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.fit_transform(x_test)

# %%
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.fit_transform(x_test)

# %%
x_train_poly
# Out:
# array([[ 1.00000000e+00, -2.72817651e+00,  7.44294709e+00,
#         -2.03056735e+01],
#        [ 1.00000000e+00, -2.19447350e+00,  4.81571396e+00,
#         -1.05679567e+01],
#        [ 1.00000000e+00,  1.80997877e+00,  3.27602316e+00,
#          5.92953238e+00],
#        [ 1.00000000e+00,  2.46708435e+00,  6.08650520e+00,
#          1.50159217e+01],
#        [ 1.00000000e+00, -8.70585779e-01,  7.57919599e-01,
#         -6.59834025e-01],
#        [ 1.00000000e+00, -1.49704753e+00,  2.24115132e+00,
#         -3.35511006e+00],
#        [ 1.00000000e+00,  1.79419998e+00,  3.21915357e+00,
#          5.77580526e+00],
#        [ 1.00000000e+00,  2.26183125e+00,  5.11588062e+00,
#          1.15712587e+01],
#        [ 1.00000000e+00, -1.92590007e+00,  3.70909106e+00,
#         -7.14333872e+00],
#        [ 1.00000000e+00, -2.47793407e+00,  6.14015725e+00,
#         -1.52149048e+01],
#        [ 1.00000000e+00,  1.42948617e+00,  2.04343070e+00,
#          2.92105592e+00],
# ...

# %%
from sklearn.metrics import r2_score
regression = LinearRegression()
regression.fit(x_train_poly , y_train)
y_pred = regression.predict(x_test_poly)
score = r2_score(y_test , y_pred)
print(score)
# Out:
# 0.8675749769793027

# %%
x_new = np.linspace(-3,3,30).reshape(30,1)
x_new_poly = poly.transform(x_new)
x_new_poly
# Out:
# array([[ 1.00000000e+00, -3.00000000e+00,  9.00000000e+00,
#         -2.70000000e+01],
#        [ 1.00000000e+00, -2.79310345e+00,  7.80142687e+00,
#         -2.17901923e+01],
#        [ 1.00000000e+00, -2.58620690e+00,  6.68846611e+00,
#         -1.72977572e+01],
#        [ 1.00000000e+00, -2.37931034e+00,  5.66111772e+00,
#         -1.34695559e+01],
#        [ 1.00000000e+00, -2.17241379e+00,  4.71938169e+00,
#         -1.02524499e+01],
#        [ 1.00000000e+00, -1.96551724e+00,  3.86325803e+00,
#         -7.59330026e+00],
#        [ 1.00000000e+00, -1.75862069e+00,  3.09274673e+00,
#         -5.43896839e+00],
#        [ 1.00000000e+00, -1.55172414e+00,  2.40784780e+00,
#         -3.73631555e+00],
#        [ 1.00000000e+00, -1.34482759e+00,  1.80856124e+00,
#         -2.43220304e+00],
#        [ 1.00000000e+00, -1.13793103e+00,  1.29488704e+00,
#         -1.47349215e+00],
#        [ 1.00000000e+00, -9.31034483e-01,  8.66825208e-01,
#         -8.07044159e-01],
# ...

# %%
y_new = regression.predict(x_test_poly)
plt.plot(x_new  , y_new , "r-" , linewidth= 2 , label = "Predictions")
plt.plot(x_train , y_train , "b." ,  label = 'Training Points')
plt.plot(x_test , y_test , "g." , label = "Testing Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
from sklearn.pipeline import Pipeline

# %%
def poly_reg(degree):
  x_new = np.linspace(-3,3,200).reshape(200,1)

  poly_features = PolynomialFeatures(degree = degree , include_bias = True)
  lin_reg = LinearRegression()
  poly_reg = Pipeline([("poly_features" , poly_features) , ("lin_reg" , lin_reg)])
  poly_reg.fit(x_train , y_train)
  y_pred_new = poly_reg.predict(x_new)

  ## Plotting Prediction Line
  plt.plot(x_new , y_pred_new , "r-" , linewidth = 2 , label = "Degree" + str(degree))
  plt.plot(x_train , y_train , "b." , linewidth = 3)
  plt.plot(x_test , y_test , "g." , linewidth = 3)

  plt.legend(loc = "upper left")
  plt.xlabel("X")
  plt.ylabel("Y")
  plt.axis([-4,4,0,10])
  plt.show()

# %%
poly_reg(1)

# %%
poly_reg(2)

# %%
poly_reg(3)

# %%
poly_reg(4)

# %%
poly_reg(10)  ###Starts the Overfitting

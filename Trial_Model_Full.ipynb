# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Quality_of_Life.csv')
df.head()
# Out:
#          country  Purchasing Power Value Purchasing Power Category  \
# 0    Afghanistan                   32.15                'Very Low'
# 1  Aland Islands                  125.01               'Very High'
# 2        Albania                   42.82                     'Low'
# 3       Alderney                    0.00                       NaN
# 4        Algeria                   27.60                'Very Low'
#
#    Safety Value Safety Category  Health Care Value Health Care Category  \
# 0         25.33           'Low'              24.24                'Low'
# 1         71.81          'High'              79.72               'High'
# 2         55.52      'Moderate'              48.21           'Moderate'
# 3         83.79     'Very High'             100.00          'Very High'
# 4         47.54      'Moderate'              54.43           'Moderate'
#
#    Climate Value Climate Category  Cost of Living Value  \
# 0           0.00              NaN                 21.08
# ...

# %%
df.isnull().sum()
# Out:
# country                                0
# Purchasing Power Value                 0
# Purchasing Power Category             46
# Safety Value                           0
# Safety Category                        2
# Health Care Value                      0
# Health Care Category                  15
# Climate Value                          0
# Climate Category                     122
# Cost of Living Value                   0
# Cost of Living Category               45
# Property Price to Income Value         0
# Property Price to Income Category     21
# Traffic Commute Time Value             0
# Traffic Commute Time Category         29
# Pollution Value                        0
# Pollution Category                    10
# Quality of Life Value                  0
# Quality of Life Category             122
# dtype: int64

# %%
df.columns
# Out:
# Index(['country', 'Purchasing Power Value', 'Purchasing Power Category',
#        'Safety Value', 'Safety Category', 'Health Care Value',
#        'Health Care Category', 'Climate Value', 'Climate Category',
#        'Cost of Living Value', 'Cost of Living Category',
#        'Property Price to Income Value', 'Property Price to Income Category',
#        'Traffic Commute Time Value', 'Traffic Commute Time Category',
#        'Pollution Value', 'Pollution Category', 'Quality of Life Value',
#        'Quality of Life Category'],
#       dtype='object')

# %%
df.drop('Climate Category' , axis = 1 , inplace = True)

# %%
df.head()
# Out:
#          country  Purchasing Power Value Purchasing Power Category  \
# 0    Afghanistan                   32.15                'Very Low'
# 1  Aland Islands                  125.01               'Very High'
# 2        Albania                   42.82                     'Low'
# 3       Alderney                    0.00                       NaN
# 4        Algeria                   27.60                'Very Low'
#
#    Safety Value Safety Category  Health Care Value Health Care Category  \
# 0         25.33           'Low'              24.24                'Low'
# 1         71.81          'High'              79.72               'High'
# 2         55.52      'Moderate'              48.21           'Moderate'
# 3         83.79     'Very High'             100.00          'Very High'
# 4         47.54      'Moderate'              54.43           'Moderate'
#
#    Climate Value  Cost of Living Value Cost of Living Category  \
# ...

# %%
df.isnull().sum()
# Out:
# country                                0
# Purchasing Power Value                 0
# Purchasing Power Category             46
# Safety Value                           0
# Safety Category                        2
# Health Care Value                      0
# Health Care Category                  15
# Climate Value                          0
# Cost of Living Value                   0
# Cost of Living Category               45
# Property Price to Income Value         0
# Property Price to Income Category     21
# Traffic Commute Time Value             0
# Traffic Commute Time Category         29
# Pollution Value                        0
# Pollution Category                    10
# Quality of Life Value                  0
# Quality of Life Category             122
# dtype: int64

# %%
df.drop('Quality of Life Category' , axis = 1 , inplace = True)

# %%
df.isnull().sum()
# Out:
# country                               0
# Purchasing Power Value                0
# Purchasing Power Category            46
# Safety Value                          0
# Safety Category                       2
# Health Care Value                     0
# Health Care Category                 15
# Climate Value                         0
# Cost of Living Value                  0
# Cost of Living Category              45
# Property Price to Income Value        0
# Property Price to Income Category    21
# Traffic Commute Time Value            0
# Traffic Commute Time Category        29
# Pollution Value                       0
# Pollution Category                   10
# Quality of Life Value                 0
# dtype: int64

# %%
df.head()
# Out:
#          country  Purchasing Power Value Purchasing Power Category  \
# 0    Afghanistan                   32.15                'Very Low'
# 1  Aland Islands                  125.01               'Very High'
# 2        Albania                   42.82                     'Low'
# 3       Alderney                    0.00                       NaN
# 4        Algeria                   27.60                'Very Low'
#
#    Safety Value Safety Category  Health Care Value Health Care Category  \
# 0         25.33           'Low'              24.24                'Low'
# 1         71.81          'High'              79.72               'High'
# 2         55.52      'Moderate'              48.21           'Moderate'
# 3         83.79     'Very High'             100.00          'Very High'
# 4         47.54      'Moderate'              54.43           'Moderate'
#
#    Climate Value  Cost of Living Value Cost of Living Category  \
# ...

# %%
list = ['country', 'Purchasing Power Category' , 'Safety Category' , 'Health Care Category' , 'Cost of Living Category' , 'Property Price to Income Category' , 'Traffic Commute Time Category' , 'Pollution Category']

# %%
for i in list:
    df.drop(i , axis = 1 , inplace = True)

# %%
df.head()
# Out:
#    Purchasing Power Value  Safety Value  Health Care Value  Climate Value  \
# 0                   32.15         25.33              24.24           0.00
# 1                  125.01         71.81              79.72           0.00
# 2                   42.82         55.52              48.21          86.43
# 3                    0.00         83.79             100.00           0.00
# 4                   27.60         47.54              54.43          94.82
#
#    Cost of Living Value Property Price to Income Value  \
# 0                 21.08                            7.8
# 1                 53.44                           5.33
# 2                 40.85                          14.88
# 3                  0.00                            0.0
# 4                 25.31                           21.7
#
#    Traffic Commute Time Value  Pollution Value Quality of Life Value
# 0                       56.17            84.44                   0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Purchasing Power Value          236 non-null    float64
#  1   Safety Value                    236 non-null    float64
#  2   Health Care Value               236 non-null    float64
#  3   Climate Value                   236 non-null    float64
#  4   Cost of Living Value            236 non-null    float64
#  5   Property Price to Income Value  236 non-null    object
#  6   Traffic Commute Time Value      236 non-null    float64
#  7   Pollution Value                 236 non-null    float64
#  8   Quality of Life Value           236 non-null    object
# dtypes: float64(7), object(2)
# memory usage: 16.7+ KB

# %%
df[df.isnull().any(axis =1 )]
# Out:
# Empty DataFrame
# Columns: [Purchasing Power Value, Safety Value, Health Care Value, Climate Value, Cost of Living Value, Property Price to Income Value, Traffic Commute Time Value, Pollution Value, Quality of Life Value]
# Index: []

# %%
df = df.dropna().reset_index(drop=True)

# %%
df.tail()
# Out:
#      Purchasing Power Value  Safety Value  Health Care Value  Climate Value  \
# 231                    0.00          0.00               0.00           0.00
# 232                    0.00         62.87               0.00           0.00
# 233                   20.74         34.07              25.31           0.00
# 234                   22.32         54.39              54.44           0.00
# 235                   28.76         39.31              44.80          96.76
#
#      Cost of Living Value Property Price to Income Value  \
# 231                  0.00                            0.0
# 232                  0.00                          12.75
# 233                 48.66                          15.98
# 234                 36.74                          72.42
# 235                 35.36                          17.35
#
#      Traffic Commute Time Value  Pollution Value Quality of Life Value
# 231                        0.00             0.00                   0.0
# ...

# %%
df.columns
# Out:
# Index(['Purchasing Power Value', 'Safety Value', 'Health Care Value',
#        'Climate Value', 'Cost of Living Value',
#        'Property Price to Income Value', 'Traffic Commute Time Value',
#        'Pollution Value', 'Quality of Life Value'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Purchasing Power Value', 'Safety Value', 'Health Care Value',
#        'Climate Value', 'Cost of Living Value',
#        'Property Price to Income Value', 'Traffic Commute Time Value',
#        'Pollution Value', 'Quality of Life Value'],
#       dtype='object')

# %%
objects = [features for features in df.columns if df[features].dtype == 'O']

# %%
df['Quality of Life Value'] = (
    df['Quality of Life Value']
    .str.replace(':', '')
    .str.strip()

)

# %%
df.head()
# Out:
#    Purchasing Power Value  Safety Value  Health Care Value  Climate Value  \
# 0                   32.15         25.33              24.24           0.00
# 1                  125.01         71.81              79.72           0.00
# 2                   42.82         55.52              48.21          86.43
# 3                    0.00         83.79             100.00           0.00
# 4                   27.60         47.54              54.43          94.82
#
#    Cost of Living Value Property Price to Income Value  \
# 0                 21.08                            7.8
# 1                 53.44                           5.33
# 2                 40.85                          14.88
# 3                  0.00                            0.0
# 4                 25.31                           21.7
#
#    Traffic Commute Time Value  Pollution Value Quality of Life Value
# 0                       56.17            84.44                   0.0
# ...

# %%
df['Quality of Life Value'] = (
    df['Quality of Life Value']
    .str.replace(':', '')
    .str.replace(r'[()"\'"]', '', regex=True)
    .str.strip('')

)

# %%
df.head()
# Out:
#    Purchasing Power Value  Safety Value  Health Care Value  Climate Value  \
# 0                   32.15         25.33              24.24           0.00
# 1                  125.01         71.81              79.72           0.00
# 2                   42.82         55.52              48.21          86.43
# 3                    0.00         83.79             100.00           0.00
# 4                   27.60         47.54              54.43          94.82
#
#    Cost of Living Value Property Price to Income Value  \
# 0                 21.08                            7.8
# 1                 53.44                           5.33
# 2                 40.85                          14.88
# 3                  0.00                            0.0
# 4                 25.31                           21.7
#
#    Traffic Commute Time Value  Pollution Value Quality of Life Value
# 0                       56.17            84.44                   0.0
# ...

# %%
df['Quality of Life Value'] = df['Quality of Life Value'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Purchasing Power Value          236 non-null    float64
#  1   Safety Value                    236 non-null    float64
#  2   Health Care Value               236 non-null    float64
#  3   Climate Value                   236 non-null    float64
#  4   Cost of Living Value            236 non-null    float64
#  5   Property Price to Income Value  236 non-null    object
#  6   Traffic Commute Time Value      236 non-null    float64
#  7   Pollution Value                 236 non-null    float64
#  8   Quality of Life Value           236 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 16.7+ KB

# %%
cleaned_dataset = pd.read_csv('cleaned_dataset.csv')
df = cleaned_dataset

# %%
df
# Out:
#      Purchasing Power Value  Safety Value  Health Care Value  Climate Value  \
# 0                     32.15         25.33              24.24           0.00
# 1                    125.01         71.81              79.72           0.00
# 2                     42.82         55.52              48.21          86.43
# 3                      0.00         83.79             100.00           0.00
# 4                     27.60         47.54              54.43          94.82
# ..                      ...           ...                ...            ...
# 231                    0.00          0.00               0.00           0.00
# 232                    0.00         62.87               0.00           0.00
# 233                   20.74         34.07              25.31           0.00
# 234                   22.32         54.39              54.44           0.00
# 235                   28.76         39.31              44.80          96.76
#
# ...

# %%
plt.scatter(df['Quality of Life Value'] , df['Cost of Living Value'])
plt.xlabel('Quality of Life Value')
plt.ylabel('Cost of Living Value')
plt.legend()
# Out:
# <ipython-input-102-887063247927>:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df.head()
# Out:
#    Purchasing Power Value  Safety Value  Health Care Value  Climate Value  \
# 0                   32.15         25.33              24.24           0.00
# 1                  125.01         71.81              79.72           0.00
# 2                   42.82         55.52              48.21          86.43
# 3                    0.00         83.79             100.00           0.00
# 4                   27.60         47.54              54.43          94.82
#
#    Cost of Living Value  Property Price to Income Value  \
# 0                 21.08                            7.80
# 1                 53.44                            5.33
# 2                 40.85                           14.88
# 3                  0.00                            0.00
# 4                 25.31                           21.70
#
#    Traffic Commute Time Value  Pollution Value  Quality of Life Value
# 0                       56.17            84.44                   0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Purchasing Power Value          236 non-null    float64
#  1   Safety Value                    236 non-null    float64
#  2   Health Care Value               236 non-null    float64
#  3   Climate Value                   236 non-null    float64
#  4   Cost of Living Value            236 non-null    float64
#  5   Property Price to Income Value  236 non-null    float64
#  6   Traffic Commute Time Value      236 non-null    float64
#  7   Pollution Value                 236 non-null    float64
#  8   Quality of Life Value           236 non-null    float64
# dtypes: float64(9)
# memory usage: 16.7 KB

# %%
df.corr()
# Out:
#                                 Purchasing Power Value  Safety Value  \
# Purchasing Power Value                        1.000000      0.333808
# Safety Value                                  0.333808      1.000000
# Health Care Value                             0.377624      0.359591
# Climate Value                                 0.274323      0.104646
# Cost of Living Value                          0.604519      0.112718
# Property Price to Income Value               -0.130004     -0.134195
# Traffic Commute Time Value                    0.141160     -0.234681
# Pollution Value                              -0.159466     -0.368183
# Quality of Life Value                         0.497247      0.262312
#
#                                 Health Care Value  Climate Value  \
# Purchasing Power Value                   0.377624       0.274323
# Safety Value                             0.359591       0.104646
# Health Care Value                        1.000000       0.357213
# ...

# %%
import seaborn as sns

sns.pairplot(df)

# %%
sns.heatmap(df.corr() , annot = True)
# Out:
# <Axes: >

# %%
x = df.drop('Cost of Living Value' , axis = 1)
y = df['Cost of Living Value']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x ,y , test_size = 0.2 , random_state = 21)

# %%
x_train.shape , x_test.shape
# Out:
# ((188, 8), (48, 8))

# %%
y_train.shape , y_test.shape
# Out:
# ((188,), (48,))

# %%
def correlation(dataset , threshold):
  col_corr = set()
  corr_matrix = dataset.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[i , j]) > threshold:
        colname = corr_matrix.columns[i]
        col_corr.add(colname)
  return col_corr

# %%
corr_features = correlation(x_train , 0.85)

# %%
corr_features
# Out:
# {'Quality of Life Value'}

# %%
x_train.drop(corr_features , axis = 1 , inplace = True)
x_test.drop(corr_features , axis = 1 , inplace = True)
x_train.shape , x_test.shape
# Out:
# ((188, 7), (48, 7))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_scaled = sc.fit_transform(x_train)
x_test_scaled = sc.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-0.53200065, -1.14079033, -0.76131201, ...,  2.72668063,
#          0.03123005,  0.40819904],
#        [ 1.61010454, -0.13200396,  0.86040517, ..., -0.22993005,
#          0.5147514 , -1.03014517],
#        [-0.37934352, -0.94442123,  0.61808529, ..., -0.14816844,
#          1.06612539,  0.37126805],
#        ...,
#        [ 2.16559596, -0.72889417, -2.75958739, ..., -0.19497339,
#          0.81068015,  0.4549521 ],
#        [-0.62010225,  0.04101638,  0.29532112, ..., -0.16388213,
#         -0.08280801,  0.03928202],
#        [-1.08945423, -0.02483911, -0.45088593, ..., -0.09220418,
#          0.56321757,  0.57085255]])

# %%
x_test_scaled
# Out:
# array([[ 1.32892503e+00,  8.58223148e-01,  3.14075004e-01,
#         -9.16201090e-01, -2.26652865e-01, -5.45232316e-01,
#         -1.14172391e+00],
#        [-1.08945423e+00,  4.76261303e-01, -2.75958739e+00,
#         -9.16201090e-01, -1.92116359e-01, -1.62232174e+00,
#         -2.08307128e+00],
#        [-3.66000739e-01, -1.33536337e+00, -2.16955942e-01,
#          8.34881459e-01, -1.29597719e-01,  9.15024970e-01,
#          5.22135074e-01],
#        [-3.44809261e-01,  1.20042968e-01,  5.56888411e-01,
#          5.81686371e-01, -1.12707602e-01,  7.31993893e-01,
#          7.60614981e-01],
#        [-1.08945423e+00,  3.03240969e-01, -2.91971466e-01,
#         -9.16201090e-01, -1.28925475e-01, -7.67036331e-01,
#         -6.60442386e-01],
#        [ 1.28752316e+00,  1.78379213e+00,  9.69473793e-01,
#         -9.16201090e-01, -2.23375679e-01, -8.62258107e-01,
#         -1.18022643e+00],
#        [-1.08945423e+00, -3.51123133e-01, -2.75958739e+00,
# ...

# %%
plt.subplots(figsize = (15,5))
plt.subplot(1,2,1)
sns.boxplot(data = x_train_scaled)
plt.title('X Train before Scaling')
plt.subplot(1,2,2)
sns.boxplot(data = x_test_scaled)
plt.title('X Train after Scaling')
# Out:
# Text(0.5, 1.0, 'X Train after Scaling')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score , mean_absolute_error
lr = LinearRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test_scaled)
mse = mean_squared_error(y_test , y_pred)
mae = mean_absolute_error(y_test , y_pred)
r2 = r2_score(y_test , y_pred)
print(f"Mean Squared Error : {mse}")
print(f"R2 Score : {r2}")
print(f"Mean Absolute Error : {mae}")
plt.scatter(y_test , y_pred)
# Out:
# Mean Squared Error : 286.80972280292053
# R2 Score : 0.5882901104521262
# Mean Absolute Error : 11.469418938649332

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score
lasso = Lasso()
lasso.fit(x_train_scaled , y_train)
y_pred = lasso.predict(x_test_scaled)
mse = mean_squared_error(y_test , y_pred)
mae = mean_absolute_error(y_test , y_pred)
r2 = r2_score(y_test , y_pred)
print(f"Mean Squared Error : {mse}")
print(f"R2 Score : {r2}")
print(f"Mean Absolute Error : {mae}")
plt.scatter(y_test , y_pred)
# Out:
# Mean Squared Error : 254.44970746839587
# R2 Score : 0.6347422955766153
# Mean Absolute Error : 11.442453730806632

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score
ridge = Ridge()
ridge.fit(x_train_scaled , y_train)
y_pred = ridge.predict(x_test_scaled)
mse = mean_squared_error(y_test , y_pred)
mae = mean_absolute_error(y_test , y_pred)
r2 = r2_score(y_test , y_pred)
print(f"Mean Squared Error : {mse}")
print(f"R2 Score : {r2}")
print(f"Mean Absolute Error : {mae}")
plt.scatter(y_test , y_pred)
# Out:
# Mean Squared Error : 283.33389525850885
# R2 Score : 0.5932795946314353
# Mean Absolute Error : 11.421945714566371

# %%
from sklearn.linear_model import RidgeCV
ridge_cv = RidgeCV(cv=5)
ridge_cv.fit(x_train_scaled , y_train)
y_pred = ridge_cv.predict(x_test_scaled)
plt.scatter(y_test , y_pred)
mae = mean_absolute_error(y_test , y_pred)
mse = mean_squared_error(y_test , y_pred)
r2 = r2_score(y_test , y_pred)
print(f"Mean Squared Error : {mse}")
print(f"R2 Score : {r2}")
print(f"Mean Absolute Error : {mae}")
# Out:
# Mean Squared Error : 258.37281214207314
# R2 Score : 0.6291107536048172
# Mean Absolute Error : 11.110183565906345

# %%
ridge_cv.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': None,
#  'store_cv_values': 'deprecated'}

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score
elasticnet = ElasticNet()
elasticnet.fit(x_train_scaled , y_train)
y_pred = elasticnet.predict(x_test_scaled)
mae = mean_absolute_error(y_test , y_pred)
mse = mean_squared_error(y_test , y_pred)
r2 = r2_score(y_test , y_pred)
print(f"Mean Squared Error : {mse}")
print(f"R2 Score : {r2}")
print(f"Mean Absolute Error : {mae}")
plt.scatter(y_test , y_pred)
# Out:
# Mean Squared Error : 260.08828989530343
# R2 Score : 0.6266482179926978
# Mean Absolute Error : 12.383223166371975

# %%
sc
# Out:
# StandardScaler()

# %%
lasso
# Out:
# Lasso()

# %%
import pickle
pickle.dump(sc , open('sc.pkl' , 'wb'))
pickle.dump(lasso , open('lasso.pkl' , 'wb'))
